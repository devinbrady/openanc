# %% [markdown]
# # Process Election Results

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/dcboe/November_3_2020_General_Election_Pre-certified_Results.csv')
df = df.rename(columns={
    'Candidate': 'candidate_name'
    , 'ContestName': 'contest_name'
    , 'ContestNumber': 'contest_number'
    , 'Votes': 'votes'
})

# %%
df[df['candidate_name'] == 'DEM Joseph R. Biden - Kamala D. Harris'].votes.sum()
# Out:
# 317323

# %%
anc = df[df['contest_name'].str.contains('SINGLE MEMBER DISTRICT')].copy()

# %%
anc.groupby('contest_name').votes.sum()
# Out:
# contest_name
# ANC - 1A01 SINGLE MEMBER DISTRICT  01-ANC 1A     519
# ANC - 1A02 SINGLE MEMBER DISTRICT  02-ANC 1A     797
# ANC - 1A03 SINGLE MEMBER DISTRICT  03-ANC 1A     616
# ANC - 1A04 SINGLE MEMBER DISTRICT  04-ANC 1A     705
# ANC - 1A05 SINGLE MEMBER DISTRICT  05-ANC 1A     631
#                                                 ...
# ANC - 8E03 SINGLE MEMBER DISTRICT  03-ANC 8E     104
# ANC - 8E04 SINGLE MEMBER DISTRICT  04-ANC 8E     866
# ANC - 8E05 SINGLE MEMBER DISTRICT  05-ANC 8E    1049
# ANC - 8E06 SINGLE MEMBER DISTRICT  06-ANC 8E     849
# ANC - 8E07 SINGLE MEMBER DISTRICT  07-ANC 8E     907
# Name: votes, Length: 296, dtype: int64

# %%
anc['smd_id'] = 'smd_' + anc['contest_name'].str[6:10]

# %%
anc[anc['smd_id'] == 'smd_1C07']
# Out:
#                ElectionDate      ElectionName  contest_number  \
# 1776  11/3/2020 12:00:00 AM  General Election              48
# 1777  11/3/2020 12:00:00 AM  General Election              48
# 2550  11/3/2020 12:00:00 AM  General Election              48
# 2551  11/3/2020 12:00:00 AM  General Election              48
#
#                                       contest_name  PrecinctNumber  \
# 1776  ANC - 1C07 SINGLE MEMBER DISTRICT  07-ANC 1C              24
# 1777  ANC - 1C07 SINGLE MEMBER DISTRICT  07-ANC 1C              24
# 2550  ANC - 1C07 SINGLE MEMBER DISTRICT  07-ANC 1C              35
# 2551  ANC - 1C07 SINGLE MEMBER DISTRICT  07-ANC 1C              35
#
#       WardNumber candidate_name Party  votes    smd_id
# 1776           1   Japer Bowles   NPN    728  smd_1C07
# 1777           1       Write-in   NPN     46  smd_1C07
# 2550           1   Japer Bowles   NPN    192  smd_1C07
# 2551           1       Write-in   NPN     22  smd_1C07

# %%
candidates = anc.groupby(['smd_id', 'contest_number', 'candidate_name']).votes.sum().reset_index()
candidates
# Out:
#        smd_id  contest_number                      candidate_name  votes
# 0    smd_1A01              18                        Layla Bonnot    501
# 1    smd_1A01              18                            Write-in     18
# 2    smd_1A02              19              Dieter Lehmann Morales    761
# 3    smd_1A02              19                            Write-in     36
# 4    smd_1A03              20                            Write-in     18
# ..        ...             ...                                 ...    ...
# 693  smd_8E06             312               Karlene (K.) Armstead    317
# 694  smd_8E06             312                            Write-in     22
# 695  smd_8E07             313  Jeannina "Ward 8 Matters" Williams    721
# 696  smd_8E07             313                Stephen A. Slaughter    177
# 697  smd_8E07             313                            Write-in      9
#
# [698 rows x 4 columns]

# %%
import hashlib
def hash_dataframe(df, columns_to_hash):
    """
    Given a DataFrame, hash certain columns

    df = pandas DataFrame
    columns_to_hash = a list containing the column names that should be hashed
    """

    hash_of_data = []

    for idx, row in df.iterrows():
        list_to_hash = row[columns_to_hash]
        string_to_hash = ','.join(list_to_hash)
        hash_of_data += [hashlib.sha224(string_to_hash.encode()).hexdigest()]
    
    return hash_of_data

# %%
candidates['dcboe_hash_id'] = hash_dataframe(candidates, ['smd_id', 'candidate_name'])

# %%
candidates['ranking'] = candidates.groupby('smd_id').votes.rank(method='first', ascending=False)
candidates['winner'] = candidates['ranking'] == 1

# %%
candidates['write_in_winner'] = candidates['winner'] & (candidates['candidate_name'] == 'Write-in')

# %%
candidates = candidates.sort_values(by=['smd_id', 'votes'], ascending=[True, False])

# %%
total_votes = candidates.groupby('smd_id').votes.sum()
total_votes.name = 'total_votes'
candidates = pd.merge(candidates, total_votes, how='inner', on='smd_id')
candidates['vote_share'] = candidates['votes'] / candidates['total_votes']

# %%
shift_one = candidates[['smd_id', 'votes', 'vote_share']].shift(-1)
shift_one = shift_one.rename(columns={
    'smd_id': 'smd_id_shifted'
    , 'votes': 'votes_shifted'
    , 'vote_share': 'vote_share_shifted'
})

candidates = pd.concat([candidates, shift_one], axis=1)

# %%
candidates['margin_of_victory'] = None
candidates['margin_of_victory_percentage'] = None
contested_winners = (candidates['smd_id'] == candidates['smd_id_shifted']) & (candidates['winner'])

candidates.loc[contested_winners, 'margin_of_victory'] = candidates['votes'] - candidates['votes_shifted']
candidates.loc[contested_winners, 'margin_of_victory_percentage'] = candidates['vote_share'] - candidates['vote_share_shifted']

# %%
num_candidates = candidates.groupby('smd_id').candidate_name.count()
num_candidates.name = 'num_candidates'
candidates = pd.merge(candidates, num_candidates, how='inner', on='smd_id')

# %%
candidates[[
    'dcboe_hash_id'
    , 'smd_id'
    , 'contest_number'
    , 'candidate_name'
    , 'votes'
    , 'vote_share'
    , 'ranking'
    , 'winner'
    , 'write_in_winner'
    , 'margin_of_victory'
    , 'margin_of_victory_percentage'
    , 'num_candidates'
    , 'total_votes'
]].to_csv('../data/dcboe/candidate_votes.csv', index=False)

# %% [markdown]
# ## Counts

# %%
candidates.sort_values(by='margin_of_victory_percentage').head(20)
# Out:
#        smd_id  contest_number             candidate_name  votes  \
# 522  smd_7B01             244           Chioma J. Iwuoha    515
# 431  smd_5E10             205              Sally Hobaugh    636
# 628  smd_8A07             285              Steven Tiller    367
# 634  smd_8B03             288          Charles H. Wilson    299
# 130  smd_2E02              78             Jenny Mitchell    276
# 366  smd_5B05             181           Colleen Costello    604
# 324  smd_4C10             162              Jonah Goodman    560
# 182  smd_3C05             102          Sauleh A Siddiqui    577
# 580  smd_7E04             268              Natasha Dupee    486
# 398  smd_5D05             193              Sydelle Moore    432
# 29   smd_1B04              33          Deborah R. Thomas    552
# 447  smd_6A06             211               Robb Dooling    621
# 94   smd_2B01              63  Margaret Ellen Roggensack    424
# 675  smd_8D06             305             Alyse Newhouse    486
# 85   smd_2A03              57     Trupti "Trip" J. Patel    291
# 250  smd_3G04             132             Michael Zeldin    667
# 689  smd_8E05             311             Shaquan Hudson    549
# 576  smd_7E02             266          Tiera J. Fletcher    591
# 281  smd_4B03             146    Jocelynn "J.J." Johnson    562
# 383  smd_5C06             187        Harry L Thomas, III    432
#
#                                          dcboe_hash_id  ranking  winner  \
# 522  5c3624c4c0a33fd119712d05ce5b6143d85141ad71498f...      1.0    True
# 431  87c0a433075547ef887b20a4ff5682ad199b65aa0b8d45...      1.0    True
# 628  53027debfd0d0d7788549943a62fa7db6f8b2e4fde75d5...      1.0    True
# 634  9a72c179f4b4c0aef1f12f8e24d7e330be6298706889e4...      1.0    True
# 130  f51d42bb8b3eefa298538a5c9b84ec7fa048a881233df4...      1.0    True
# 366  0ab458e64c2af7777f9e9e5b0417e1f6ff1831e93c98dc...      1.0    True
# 324  2dfc6d733bb4cf95c4ceb2da45fa3243525bc0441f1182...      1.0    True
# 182  94bcd86cb01050f6369358fdfe415ac7d6c0a891b14c8a...      1.0    True
# 580  deb5e54ddfd46cd4e2cb518700d5faf834a9c3197d34c8...      1.0    True
# 398  f7dd6fc22c57dd50b15e0db3c07218fe1af71454a93e90...      1.0    True
# 29   eeff03abb5f1fd553854b9b447399b4be872b6b91c3aad...      1.0    True
# 447  ee8a31b72f7deeccd3f409401fe5a2021fc6f5cf9f6e97...      1.0    True
# 94   d494f9bb32d635f3d20d2a0d50deef9809d8e22c88c977...      1.0    True
# 675  a0c9e3ccebab90fbfdd9f8476fe56780a9524188f4fd4d...      1.0    True
# 85   fe0ed8e2962c47ff06bb27df80e7c440c66019905ca70b...      1.0    True
# 250  430d9e057fa06f4821919b9884b4c28a2116eeb4243a5c...      1.0    True
# 689  6ce81c78f013eea91b0c559d4ed6401521fdf3c1ce197a...      1.0    True
# 576  ffa6384ada63e729f9ff53d43f430088a5bdaac7cbb85a...      1.0    True
# 281  59c35ca1ff3c01abc2c0b6db4cc10b64b6531fb1582243...      1.0    True
# 383  a8f2e3069cd7767301a6930a0fc8741315c9952389eba9...      1.0    True
#
#      write_in_winner  total_votes  vote_share smd_id_shifted  votes_shifted  \
# 522            False         1039    0.495669       smd_7B01          513.0
# 431            False         1270    0.500787       smd_5E10          627.0
# 628            False         1093    0.335773       smd_8A07          359.0
# 634            False          864    0.346065       smd_8B03          287.0
# 130            False          546    0.505495       smd_2E02          262.0
# 366            False         1205    0.501245       smd_5B05          568.0
# 324            False         1105    0.506787       smd_4C10          524.0
# 182            False         1201    0.480433       smd_3C05          533.0
# 580            False         1146    0.424084       smd_7E04          444.0
# 398            False          838    0.515513       smd_5D05          396.0
# 29             False         1068    0.516854       smd_1B04          506.0
# 447            False         1281    0.484778       smd_6A06          560.0
# 94             False          817    0.518972       smd_2B01          383.0
# 675            False          933    0.520900       smd_8D06          431.0
# 85             False          554    0.525271       smd_2A03          258.0
# 250            False         1261    0.528945       smd_3G04          589.0
# 689            False         1049    0.523356       smd_8E05          482.0
# 576            False         1102    0.536298       smd_7E02          494.0
# 281            False         1057    0.531693       smd_4B03          467.0
# 383            False          854    0.505855       smd_5C06          354.0
#
#      vote_share_shifted margin_of_victory margin_of_victory_percentage  \
# 522            0.493744                 2                   0.00192493
# 431            0.493701                 9                   0.00708661
# 628            0.328454                 8                    0.0073193
# 634            0.332176                12                    0.0138889
# 130            0.479853                14                     0.025641
# 366            0.471369                36                    0.0298755
# 324            0.474208                36                    0.0325792
# 182            0.443797                44                    0.0366361
# 580            0.387435                42                    0.0366492
# 398            0.472554                36                    0.0429594
# 29             0.473783                46                    0.0430712
# 447            0.437158                61                     0.047619
# 94             0.468788                41                    0.0501836
# 675            0.461951                55                    0.0589496
# 85             0.465704                33                    0.0595668
# 250            0.467090                78                    0.0618557
# 689            0.459485                67                    0.0638704
# 576            0.448276                97                    0.0880218
# 281            0.441816                95                     0.089877
# 383            0.414520                78                    0.0913349
#
#      num_candidates
# 522               3
# 431               3
# 628               4
# 634               4
# 130               3
# 366               3
# 324               3
# 182               4
# 580               4
# 398               3
# 29                3
# 447               4
# 94                3
# 675               3
# 85                3
# 250               3
# 689               3
# 576               3
# 281               3
# 383               3

# %%
candidates['write_in_winner'].sum()
# Out:
# 25

# %%
candidates[candidates['write_in_winner']] #  & (candidates['num_candidates'] > 1)]
# Out:
#        smd_id  contest_number candidate_name  votes  \
# 22   smd_1A12              29       Write-in    144
# 82   smd_2A01              55       Write-in     33
# 88   smd_2A04              58       Write-in    221
# 89   smd_2A05              59       Write-in     51
# 92   smd_2A07              61       Write-in     27
# 93   smd_2A08              62       Write-in     13
# 127  smd_2D02              76       Write-in    166
# 144  smd_2E08              84       Write-in     13
# 255  smd_3G06             134       Write-in    350
# 337  smd_4D05             167       Write-in    186
# 346  smd_5A04             172       Write-in      3
# 470  smd_6B07             220       Write-in    301
# 491  smd_6D01             230       Write-in    425
# 492  smd_6D02             231       Write-in    611
# 528  smd_7B03             246       Write-in    170
# 573  smd_7D07             264       Write-in    193
# 579  smd_7E03             267       Write-in    106
# 601  smd_7F03             274       Write-in    113
# 610  smd_7F07             278       Write-in     23
# 632  smd_8B01             286       Write-in    165
# 633  smd_8B02             287       Write-in    103
# 645  smd_8B07             292       Write-in    100
# 661  smd_8C06             298       Write-in     78
# 674  smd_8D05             304       Write-in    142
# 686  smd_8E03             309       Write-in    104
#
#                                          dcboe_hash_id  ranking  winner  \
# 22   f77005d854c4936ad6d11f9d805bf1a2cdc25be5de9399...      1.0    True
# 82   f071e18b0f73de52fdbc66127a31f1cdc399b07ded940d...      1.0    True
# 88   c2cf6a36c67f5a5b0aa403335e73801ed26847eacf4158...      1.0    True
# 89   83b12c0c67ce97f28d86f773238936de01332efcc62442...      1.0    True
# 92   6806288ad3bfa48661f47809dc85221f795e317da0fd8c...      1.0    True
# 93   3b61e8de1119437a7835aa0196f1cc7835858795445225...      1.0    True
# 127  d6eabe94a1f41a3b05dd9652a9eae5734b58d1526e4a4e...      1.0    True
# 144  c44ba720415254e91dd45b2a3d83defac4c082669a97f7...      1.0    True
# 255  da5eaec11315736e4f56a425f926898671f2bcc325397b...      1.0    True
# 337  e6ae9f35f6a206558bb4ffa5fb9bd06964527410bc869d...      1.0    True
# 346  78d15c8a5b224beebe0a7ad6b2124e2f7d8d6dcc4f0693...      1.0    True
# 470  7a5c4e760f35bcc5f8aa57f6dd6c95137f28cf2baee899...      1.0    True
# 491  7da7d4ac2cd777feb9150a2d3d2a242be597b0ada078b0...      1.0    True
# 492  db93aabc2a22339a2ac86143a31bbeb23fd70267570718...      1.0    True
# 528  eaac5ccfb820b1afb2e22d0ca1ecad4ae7637582c12d70...      1.0    True
# 573  11345773aeda006c70108dd602ee729f0b7d72a61805aa...      1.0    True
# 579  0f4c9cfb8af5ff4b2dfbfe27c98fc88c3ee9f1894a03ec...      1.0    True
# 601  371e12c940176061e7993995447e80c0cb4f1041e91e56...      1.0    True
# 610  a55801a2ab94d5faef077b403a8b7708c3400bebc1f319...      1.0    True
# 632  bfcd00d5d163807bd2fa55de08eb275872834cce081292...      1.0    True
# 633  af0c08b4d79c0a40245c40f62c5282dd069001942135d9...      1.0    True
# 645  56dae34eb76ccc311ae753c2c9c5a85ae86eb37c04361a...      1.0    True
# 661  8f63a7de413129ea7291486ad42eb24d64df1ccbcc58d5...      1.0    True
# 674  2e1f10ff97c7e8e167fd90e268c93a11ac555414194b05...      1.0    True
# 686  e8cb54cb58d19694af1eafef4cb704d90662239f352575...      1.0    True
#
#      write_in_winner  total_votes  vote_share smd_id_shifted  votes_shifted  \
# 22              True          144         1.0       smd_1B01          880.0
# 82              True           33         1.0       smd_2A02          542.0
# 88              True          221         1.0       smd_2A05           51.0
# 89              True           51         1.0       smd_2A06          467.0
# 92              True           27         1.0       smd_2A08           13.0
# 93              True           13         1.0       smd_2B01          424.0
# 127             True          166         1.0       smd_2E01          605.0
# 144             True           13         1.0       smd_2F01          788.0
# 255             True          350         1.0       smd_3G07          754.0
# 337             True          186         1.0       smd_4D06          849.0
# 346             True            3         1.0       smd_5A05          409.0
# 470             True          301         1.0       smd_6B08          784.0
# 491             True          425         1.0       smd_6D02          611.0
# 492             True          611         1.0       smd_6D03          780.0
# 528             True          170         1.0       smd_7B04          861.0
# 573             True          193         1.0       smd_7E01          940.0
# 579             True          106         1.0       smd_7E04          486.0
# 601             True          113         1.0       smd_7F04          313.0
# 610             True           23         1.0       smd_8A01          888.0
# 632             True          165         1.0       smd_8B02          103.0
# 633             True          103         1.0       smd_8B03          299.0
# 645             True          100         1.0       smd_8C01          482.0
# 661             True           78         1.0       smd_8C07          734.0
# 674             True          142         1.0       smd_8D06          486.0
# 686             True          104         1.0       smd_8E04          791.0
#
#      vote_share_shifted margin_of_victory margin_of_victory_percentage  \
# 22             0.957563              None                         None
# 82             0.952548              None                         None
# 88             1.000000              None                         None
# 89             0.968880              None                         None
# 92             1.000000              None                         None
# 93             0.518972              None                         None
# 127            0.942368              None                         None
# 144            0.968059              None                         None
# 255            0.972903              None                         None
# 337            0.964773              None                         None
# 346            0.973810              None                         None
# 470            0.738926              None                         None
# 491            1.000000              None                         None
# 492            0.947752              None                         None
# 528            0.715116              None                         None
# 573            0.981211              None                         None
# 579            0.424084              None                         None
# 601            0.782500              None                         None
# 610            0.939683              None                         None
# 632            1.000000              None                         None
# 633            0.346065              None                         None
# 645            0.945098              None                         None
# 661            0.967062              None                         None
# 674            0.520900              None                         None
# 686            0.913395              None                         None
#
#      num_candidates
# 22                1
# 82                1
# 88                1
# 89                1
# 92                1
# 93                1
# 127               1
# 144               1
# 255               1
# 337               1
# 346               1
# 470               1
# 491               1
# 492               1
# 528               1
# 573               1
# 579               1
# 601               1
# 610               1
# 632               1
# 633               1
# 645               1
# 661               1
# 674               1
# 686               1

# %%
candidates.sort_values(by='votes', ascending=False).head(10)
# Out:
#        smd_id  contest_number             candidate_name  votes  \
# 489  smd_6C06             229              Drew Courtney   2848
# 501  smd_6D07             236             Edward Daniels   2053
# 515  smd_6E05             241          Patrick K. Parlej   1573
# 375  smd_5C03             184               Pierre Hines   1467
# 487  smd_6C05             228                 Joel Kelty   1354
# 495  smd_6D04             233                Andy Litsky   1316
# 291  smd_4B07             150            Geoff Bromaghim   1242
# 468  smd_6B06             219               Corey Holman   1186
# 497  smd_6D05             234  Fredrica ("Rikki") Kramer   1178
# 364  smd_5B04             180                    Ra Amin   1162
#
#                                          dcboe_hash_id  ranking  winner  \
# 489  014cac4dd905f3c85a0b269bf43a352ebe04c08b102b7a...      1.0    True
# 501  e03a1c254580e46525a9b4d6ef204bab0f12b224588086...      1.0    True
# 515  826fafb76a69665a2585610f5f679c7a0fb1ec0de5548c...      1.0    True
# 375  d1b97aea73c2cbd2eecec59929bb5008ac235d0836e983...      1.0    True
# 487  84edb33a0a2bed21dd3e52fbee27bae82485e5deaeaefc...      1.0    True
# 495  e4d3a374dfcf85028220dbf0963ec9ff43e9e5121beecc...      1.0    True
# 291  74ddb5ca35a50e07e4dff3aea623bbc42a674759ea3584...      1.0    True
# 468  1517ed5f34ee8200194cefac2d575ead1ecae8d2b3dc14...      1.0    True
# 497  154de7e1905ffd769138b98f0df6b1de66c0554772b9b2...      1.0    True
# 364  a36c6cd0011c818e5ca0cee688bc255fb40c2c517906c2...      1.0    True
#
#      write_in_winner  total_votes  vote_share smd_id_shifted  votes_shifted  \
# 489            False         2945    0.967063       smd_6C06           97.0
# 501            False         3116    0.658858       smd_6D07          985.0
# 515            False         1634    0.962668       smd_6E05           61.0
# 375            False         1523    0.963230       smd_5C03           56.0
# 487            False         1430    0.946853       smd_6C05           76.0
# 495            False         1369    0.961286       smd_6D04           53.0
# 291            False         1300    0.955385       smd_4B07           58.0
# 468            False         1227    0.966585       smd_6B06           41.0
# 497            False         1232    0.956169       smd_6D05           54.0
# 364            False         1212    0.958746       smd_5B04           50.0
#
#      vote_share_shifted margin_of_victory margin_of_victory_percentage  \
# 489            0.032937              2751                     0.934126
# 501            0.316110              1068                     0.342747
# 515            0.037332              1512                     0.925337
# 375            0.036770              1411                     0.926461
# 487            0.053147              1278                     0.893706
# 495            0.038714              1263                     0.922571
# 291            0.044615              1184                     0.910769
# 468            0.033415              1145                      0.93317
# 497            0.043831              1124                     0.912338
# 364            0.041254              1112                     0.917492
#
#      num_candidates
# 489               2
# 501               3
# 515               2
# 375               2
# 487               2
# 495               2
# 291               2
# 468               2
# 497               2
# 364               2

# %%
anc[anc['smd_id'] == 'smd_6C06']
# Out:
#                 ElectionDate      ElectionName  contest_number  \
# 5983   11/3/2020 12:00:00 AM  General Election             229
# 5984   11/3/2020 12:00:00 AM  General Election             229
# 10498  11/3/2020 12:00:00 AM  General Election             229
# 10499  11/3/2020 12:00:00 AM  General Election             229
#
#                                        contest_name  PrecinctNumber  \
# 5983   ANC - 6C06 SINGLE MEMBER DISTRICT  06-ANC 6C              83
# 5984   ANC - 6C06 SINGLE MEMBER DISTRICT  06-ANC 6C              83
# 10498  ANC - 6C06 SINGLE MEMBER DISTRICT  06-ANC 6C             144
# 10499  ANC - 6C06 SINGLE MEMBER DISTRICT  06-ANC 6C             144
#
#        WardNumber candidate_name Party  votes    smd_id
# 5983            6  Drew Courtney   NPN    769  smd_6C06
# 5984            6       Write-in   NPN     33  smd_6C06
# 10498           6       Write-in   NPN     64  smd_6C06
# 10499           6  Drew Courtney   NPN   2079  smd_6C06
