# %% [markdown]
# # 3) Find Neighbors 2022
#
# Look for shapes that have the same color as their neighbors, and change them to a new random color until there are no collisions.
#
# `map_color_id = 13` means that this new district is made up of less than 50% of an old district by area, so it needs a new random color.

# %%
import random
import pandas as pd
import geopandas as gp

# %%
# Let's set the random seed so we get the same colors picked every time
random.seed('DC')

# %%
df = gp.read_file('to-mapbox-2022-smd-data-colors.geojson')

df.sort_values(by='smd_id', inplace=True)

df['neighbors'] = None
df['num_neighbors'] = None
df['neighbor_colors'] = None
df['has_collision'] = False

possible_colors = list(range(1,13))

# %%
# df.loc[0].geometry[0].boundary.xy

# %%
# Determine the neighbors for each shape

for idx, row in df.iterrows():

    # get 'not disjoint' shapes
    neighbors = df[~df.geometry.disjoint(row.geometry)].smd_id.tolist()

    # remove own name from the list
    neighbors = [ name for name in neighbors if row.smd_id != name ]

    # add names of neighbors as NEIGHBORS value
    df.loc[idx, 'neighbors'] = ", ".join(neighbors)
    df.loc[idx, 'num_neighbors'] = len(neighbors)

# %%
df.groupby('num_neighbors').size()
# Out:
# num_neighbors
# 2      4
# 3     14
# 4     57
# 5     80
# 6     75
# 7     51
# 8     36
# 9     16
# 10     9
# 11     3
# dtype: int64

# %%
def assess_collisions(df):
    """
    Mark True for districts with collisions, meaning the district has the same color as a neighbor
    and needs a new color assigned. Also count map_color_id = 13 as needing a new color. 
    """
    
    for idx, row in df.iterrows():
        neighbors = row['neighbors'].split(', ')
        neighbor_colors = [df.loc[df.smd_id == n, 'map_color_id'].values[0] for n in neighbors]

        df.loc[idx, 'neighbor_colors'] = ", ".join([str(n) for n in neighbor_colors])

        if row['map_color_id'] in neighbor_colors:
            df.loc[idx, 'has_collision'] = True
    
    # color ID of 13 means this district doesn't match an old district and it also needs its color changed
    df.loc[df.map_color_id == 13, 'has_collision'] = True
    
    num_collisions = df['has_collision'].sum()
    print(f'Current collisions: {num_collisions}')

    return df, num_collisions

# %%
def least_used_color(df, available_colors):
    """
    Return the color that is used the least on the map as it stands now
    """
    
    districts_by_color = df.groupby('map_color_id').size()
    
    return districts_by_color[available_colors].idxmin()

# %%
def change_one_district_color(df):
    """Change color for one district to an available color"""
    
    smd_to_change = df[df['has_collision']].sample(1)['smd_id'].values[0]

    row = df[df['smd_id'] == smd_to_change]
    
    old_color = row['map_color_id'].values[0]

    neighbor_colors_str = row['neighbor_colors'].values[0].split(', ')
    neighbor_colors = [int(n) for n in neighbor_colors_str]
    
    available_colors = [c for c in possible_colors if c not in neighbor_colors]
    new_color = least_used_color(df, available_colors)

    df.loc[row.index, 'map_color_id'] = new_color
    df.loc[row.index, 'has_collision'] = False
    
    print(f'District {smd_to_change} changed from {old_color} to color {new_color}')
    
    return df

# %%
df, num_collisions = assess_collisions(df)

num_iterations = 200
i = 0

while num_collisions != 0 and i < num_iterations:
    i += 1
    print()
    
    df = change_one_district_color(df)
    df, num_collisions = assess_collisions(df)
# Out:
# Current collisions: 100
#
# District smd_2022_8A02 changed from 11 to color 7
# Current collisions: 99
#
# District smd_2022_6D07 changed from 13 to color 11
# Current collisions: 98
#
# District smd_2022_2A01 changed from 1 to color 11
# Current collisions: 97
#
# District smd_2022_5B06 changed from 13 to color 11
# Current collisions: 96
#
# District smd_2022_7F04 changed from 5 to color 6
# Current collisions: 95
#
# District smd_2022_8F05 changed from 13 to color 7
# Current collisions: 94
#
# District smd_2022_2B07 changed from 13 to color 5
# Current collisions: 93
#
# District smd_2022_2G01 changed from 4 to color 12
# Current collisions: 92
#
# District smd_2022_3C04 changed from 13 to color 4
# Current collisions: 91
#
# District smd_2022_6D03 changed from 13 to color 5
# Current collisions: 90
#
# District smd_2022_5D06 changed from 13 to color 11
# Current collisions: 89
#
# District smd_2022_1D01 changed from 9 to color 5
# Current collisions: 88
#
# District smd_2022_3D03 changed from 8 to color 1
# Current collisions: 87
#
# District smd_2022_5F02 changed from 13 to color 9
# Current collisions: 86
#
# District smd_2022_2C01 changed from 3 to color 7
# Current collisions: 85
#
# District smd_2022_4B04 changed from 13 to color 6
# Current collisions: 84
#
# District smd_2022_7B04 changed from 13 to color 8
# Current collisions: 83
#
# District smd_2022_8C02 changed from 13 to color 9
# Current collisions: 82
#
# District smd_2022_2F02 changed from 13 to color 10
# Current collisions: 81
#
# District smd_2022_7E07 changed from 5 to color 12
# Current collisions: 80
#
# District smd_2022_2C04 changed from 13 to color 5
# Current collisions: 79
#
# District smd_2022_4E04 changed from 13 to color 11
# Current collisions: 78
#
# District smd_2022_7B09 changed from 13 to color 1
# Current collisions: 77
#
# District smd_2022_6C05 changed from 13 to color 2
# Current collisions: 76
#
# District smd_2022_5E02 changed from 4 to color 4
# Current collisions: 75
#
# District smd_2022_8B05 changed from 13 to color 5
# Current collisions: 74
#
# District smd_2022_8E08 changed from 7 to color 4
# Current collisions: 73
#
# District smd_2022_6D04 changed from 13 to color 7
# Current collisions: 72
#
# District smd_2022_6E01 changed from 3 to color 8
# Current collisions: 71
#
# District smd_2022_1B05 changed from 13 to color 3
# Current collisions: 70
#
# District smd_2022_1E03 changed from 13 to color 10
# Current collisions: 69
#
# District smd_2022_1C05 changed from 13 to color 6
# Current collisions: 68
#
# District smd_2022_3D07 changed from 13 to color 7
# Current collisions: 67
#
# District smd_2022_7F08 changed from 13 to color 12
# Current collisions: 66
#
# District smd_2022_3C03 changed from 9 to color 9
# Current collisions: 65
#
# District smd_2022_5C01 changed from 13 to color 9
# Current collisions: 64
#
# District smd_2022_1A07 changed from 7 to color 11
# Current collisions: 63
#
# District smd_2022_6A02 changed from 13 to color 7
# Current collisions: 62
#
# District smd_2022_6D01 changed from 1 to color 1
# Current collisions: 61
#
# District smd_2022_8D01 changed from 13 to color 2
# Current collisions: 60
#
# District smd_2022_5E04 changed from 13 to color 3
# Current collisions: 59
#
# District smd_2022_4B10 changed from 13 to color 4
# Current collisions: 58
#
# District smd_2022_6B07 changed from 13 to color 1
# Current collisions: 57
#
# District smd_2022_7B03 changed from 13 to color 5
# Current collisions: 56
#
# District smd_2022_7F02 changed from 13 to color 6
# Current collisions: 55
#
# District smd_2022_3C01 changed from 13 to color 7
# Current collisions: 54
#
# District smd_2022_7B01 changed from 11 to color 10
# Current collisions: 53
#
# District smd_2022_2A08 changed from 13 to color 11
# Current collisions: 52
#
# District smd_2022_7F03 changed from 13 to color 8
# Current collisions: 51
#
# District smd_2022_6D06 changed from 13 to color 9
# Current collisions: 50
#
# District smd_2022_1E06 changed from 13 to color 12
# Current collisions: 49
#
# District smd_2022_2G04 changed from 13 to color 1
# Current collisions: 48
#
# District smd_2022_3C08 changed from 13 to color 11
# Current collisions: 47
#
# District smd_2022_8C04 changed from 13 to color 5
# Current collisions: 46
#
# District smd_2022_8C08 changed from 13 to color 2
# Current collisions: 45
#
# District smd_2022_1E07 changed from 13 to color 3
# Current collisions: 44
#
# District smd_2022_1A09 changed from 13 to color 4
# Current collisions: 43
#
# District smd_2022_1C02 changed from 13 to color 6
# Current collisions: 42
#
# District smd_2022_5A08 changed from 13 to color 7
# Current collisions: 41
#
# District smd_2022_4E02 changed from 13 to color 9
# Current collisions: 40
#
# District smd_2022_5F05 changed from 13 to color 10
# Current collisions: 39
#
# District smd_2022_2B06 changed from 13 to color 8
# Current collisions: 38
#
# District smd_2022_4C04 changed from 7 to color 2
# Current collisions: 37
#
# District smd_2022_6E05 changed from 13 to color 7
# Current collisions: 36
#
# District smd_2022_6C01 changed from 13 to color 11
# Current collisions: 35
#
# District smd_2022_6E03 changed from 13 to color 12
# Current collisions: 34
#
# District smd_2022_8E06 changed from 7 to color 1
# Current collisions: 33
#
# District smd_2022_6E02 changed from 13 to color 7
# Current collisions: 32
#
# District smd_2022_2F08 changed from 13 to color 3
# Current collisions: 31
#
# District smd_2022_1D06 changed from 13 to color 6
# Current collisions: 30
#
# District smd_2022_6E09 changed from 13 to color 4
# Current collisions: 29
#
# District smd_2022_7D10 changed from 13 to color 5
# Current collisions: 28
#
# District smd_2022_2F05 changed from 13 to color 7
# Current collisions: 27
#
# District smd_2022_8C06 changed from 13 to color 8
# Current collisions: 26
#
# District smd_2022_1B07 changed from 13 to color 9
# Current collisions: 25
#
# District smd_2022_8E09 changed from 13 to color 12
# Current collisions: 24
#
# District smd_2022_3E06 changed from 8 to color 11
# Current collisions: 23
#
# District smd_2022_2B04 changed from 13 to color 8
# Current collisions: 22
#
# District smd_2022_8F02 changed from 13 to color 10
# Current collisions: 21
#
# District smd_2022_8B01 changed from 13 to color 2
# Current collisions: 20
#
# District smd_2022_3A03 changed from 13 to color 3
# Current collisions: 19
#
# District smd_2022_4C06 changed from 13 to color 1
# Current collisions: 18
#
# District smd_2022_8B07 changed from 13 to color 5
# Current collisions: 17
#
# District smd_2022_2G02 changed from 13 to color 4
# Current collisions: 16
#
# District smd_2022_3A05 changed from 13 to color 6
# Current collisions: 15
#
# District smd_2022_4D02 changed from 13 to color 7
# Current collisions: 14
#
# District smd_2022_3E05 changed from 13 to color 8
# Current collisions: 13
#
# District smd_2022_7E01 changed from 13 to color 10
# Current collisions: 12
#
# District smd_2022_7D02 changed from 13 to color 11
# Current collisions: 11
#
# District smd_2022_3F04 changed from 13 to color 9
# Current collisions: 10
#
# District smd_2022_3E07 changed from 13 to color 1
# Current collisions: 9
#
# District smd_2022_4C02 changed from 13 to color 12
# Current collisions: 8
#
# District smd_2022_6D05 changed from 13 to color 3
# Current collisions: 7
#
# District smd_2022_8F04 changed from 13 to color 4
# Current collisions: 6
#
# District smd_2022_5A06 changed from 13 to color 2
# Current collisions: 5
#
# District smd_2022_7D07 changed from 13 to color 5
# Current collisions: 4
#
# District smd_2022_8A03 changed from 13 to color 6
# Current collisions: 3
#
# District smd_2022_5D02 changed from 13 to color 7
# Current collisions: 2
#
# District smd_2022_8F03 changed from 13 to color 8
# Current collisions: 1
#
# District smd_2022_6E06 changed from 13 to color 11
# Current collisions: 0

# %%
# Use the same field names as the 2012 geojson
previous_map = gp.read_file('../uploads/to-mapbox-smd-data.geojson')

for c in previous_map.columns:
    if c not in df.columns:
        df[c] = None

# %%
# df[df['smd_id'] == 'smd_1C07']

# %%
# df[(df['smd_id'] == 'smd_2C02') | (df['smd_id'] == 'smd_6E05') ]

# %%
df.groupby('map_color_id').size()
# Out:
# map_color_id
# 1     29
# 2     29
# 3     29
# 4     29
# 5     29
# 6     29
# 7     29
# 8     29
# 9     28
# 10    28
# 11    29
# 12    28
# dtype: int64

# %%
# Some manual fixes
df.loc[df.smd_id == 'smd_2022_1A07', 'map_color_id'] = 7
# df.loc[df.smd_id == 'smd_1A07', 'neighbors'].values

# %%
df[previous_map.columns].to_file('to-mapbox-2022-smd-data.geojson', driver='GeoJSON')

# %%
df[previous_map.columns].to_csv('to-mapbox-2022-smd-data.csv', index=False)

# %%
# Should be 345
len(df)
# Out:
# 345
