# %% [markdown]
# Make sure the DCBOE hash IDs were pasted correctly.

# %%
import os
os.chdir('../')

import pandas as pd
pd.set_option('display.max_rows', 500)

from scripts.data_transformations import list_commissioners, list_candidates

# %%
cand = list_candidates()
dcboe = pd.read_csv('data/dcboe/candidates_dcboe.csv')

# %%
cd = pd.merge(cand, dcboe, how='inner', on='dcboe_hash_id')

# %%
cd.loc[cd.candidate_name_x != cd.candidate_name_y
    , ['candidate_name_x', 'candidate_name_y', 'smd_id_x', 'smd_id_y']].sort_values(by='smd_id_x')
# Out:
#             candidate_name_x                candidate_name_y         smd_id_x  \
# 54             Amanda Farnan                 Amanda M Farnan    smd_2022_1E07
# 55    Trupti "Trip" J. Patel                 Trupti J. Patel    smd_2022_2A03
# 56           Jeff Rueckgauer              Jeffrey Rueckgauer    smd_2022_2B02
# 66           Brian J. McCabe                 Brian J. Mccabe    smd_2022_2F04
# 118             Lisa R. Gore                       Lisa Gore  smd_2022_3/4G01
# 8     Thaddeus Bradley-Lewis          Thaddeus Bradley Lewis    smd_2022_3A01
# 18             Janell Pagats             Janell Marie Pagats    smd_2022_3C03
# 120       Sauleh A. Siddiqui           Sauleh Ahmad Siddiqui    smd_2022_3C05
# 16   Quentin Colón Roosevelt        Quentin Col√Ìn Roosevelt    smd_2022_3D03
# 69               Amy B. Hall                      Amy B Hall    smd_2022_3E02
# 122             Gail Brevard                 Gail A. Brevard    smd_2022_5B07
# ...

# %%
cd.loc[cd.smd_id_x != cd.smd_id_y
    , ['candidate_name_x', 'candidate_name_y', 'smd_id_x', 'smd_id_y']].sort_values(by='smd_id_x')
# Out:
# Empty DataFrame
# Columns: [candidate_name_x, candidate_name_y, smd_id_x, smd_id_y]
# Index: []
