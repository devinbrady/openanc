# %% [markdown]
# # Candidate Data Check
#
# Make sure the DCBOE hash IDs were pasted correctly.

# %%
import os
os.chdir('../')

import pandas as pd
pd.set_option('display.max_rows', 500)

from scripts.data_transformations import list_commissioners, list_candidates

# %%
cand = list_candidates()
dcboe = pd.read_csv('data/dcboe/candidates_dcboe.csv')

# %%
cd = pd.merge(cand, dcboe, how='inner', on='dcboe_hash_id', suffixes=['_openanc', '_dcboe'])

# %% [markdown]
# ## Candidate Name Comparison
#
# These candidates have a different name in DCBOE than in OpenANC. Compare them and consider changing to match the ballot.

# %%
(
    cd.loc[cd.candidate_name_openanc != cd.candidate_name_dcboe
    , ['candidate_name_openanc', 'candidate_name_dcboe', 'smd_id_openanc', 'smd_id_dcboe']]
    .sort_values(by='smd_id_openanc')
)
# Out:
#       candidate_name_openanc                        candidate_name_dcboe  \
# 212          Mike McLaughlin                             Mike Mclaughlin
# 58             Amanda Farnan                             Amanda M Farnan
# 59    Trupti "Trip" J. Patel                         Trupti "Trip" Patel
# 68        Carson Colton Robb                                 Carson Robb
# 60           Jeff Rueckgauer                          Jeffrey Rueckgauer
# 153              Carole Feld                              Carole L. Feld
# 70           Brian J. McCabe                             Brian J. Mccabe
# 236     Carl Edgar Rohde III                        Carl Edgar Rohde Iii
# 22             Janell Pagats                         Janell Marie Pagats
# 127       Sauleh A. Siddiqui                       Sauleh Ahmad Siddiqui
# 20   Quentin Colón Roosevelt                    Quentin ColóN Roosevelt
# 156          J.P. Szymkowicz                            J. P. Szymkowicz
# 73               Amy B. Hall                                  Amy B Hall
# 78          Antonia M. Kirby                            Antoine M. Kirby
# 79     Reginald E. Black Jr.                   Reginald Eugene Black Jr.
# 129             Gail Brevard                             Gail A. Brevard
# 17                  VJ Kapur                                    Vj Kapur
# 10          Luc Saint-Genies                    Luc Raphael Saint Genies
# 25   Salvador Sauceda-Guzman  Salvador "The Commissioner" Sauceda-Guzman
# 191           Nicole McEntee                              Nicole Mcentee
# 80         Michael Velasquez                              Mike Velasquez
# 81            Robert Shapiro                             Roberta Shapiro
# 47             Laura Gentile                             Laura L Gentile
# 62             Gerald Sroufe                       Gerald "Jerry" Sroufe
# 0             Matt LaFortune                              Matt Lafortune
# 83           Rasheedah Hasan                          Rasheedah M. Hasan
# 112           Thomas Seidman                                 Tom Seidman
# 220           Víctor de León                            VíCtor De LeóN
# 199       Rhonda N. Hamilton                     Rhonda Natalie Hamilton
# 130             Kelvin Brown                           Kelvin Earl Brown
# 149           Ashley R. Ruff                           Ashley Renee Ruff
# 90         Obbie English III                               Obbie English
# 93               Devon Myers                                   Dev Myers
# 242  Bobby "Slli'm" Williams                     Bobby "Slli'M" Williams
# 64            Robin McKinney                              Robin Mckinney
# 65         Joseph B. Johnson                              Joseph Johnson
# 204         Anthony Muhammad                        Anthony Adc Muhammad
# 133          Robbie Woodland              Robbie "The Advocate" Woodland
# 162             LaQueta Tate                                Laqueda Tate
# 205           Shaquan Hudson               Shaquan "Living Proof" Hudson
# 243    Andrew McCarthy-Clark                       Andrew Mccarthy-Clark
#
#     smd_id_openanc   smd_id_dcboe
# 212  smd_2022_1E04  smd_2022_1E04
# 58   smd_2022_1E07  smd_2022_1E07
# 59   smd_2022_2A03  smd_2022_2A03
# 68   smd_2022_2A04  smd_2022_2A04
# 60   smd_2022_2B02  smd_2022_2B02
# 153  smd_2022_2D02  smd_2022_2D02
# 70   smd_2022_2F04  smd_2022_2F04
# 236  smd_2022_2G06  smd_2022_2G06
# 22   smd_2022_3C03  smd_2022_3C03
# 127  smd_2022_3C05  smd_2022_3C05
# 20   smd_2022_3D03  smd_2022_3D03
# 156  smd_2022_3D07  smd_2022_3D07
# 73   smd_2022_3E02  smd_2022_3E02
# 78   smd_2022_4C02  smd_2022_4C02
# 79   smd_2022_4E01  smd_2022_4E01
# 129  smd_2022_5B07  smd_2022_5B07
# 17   smd_2022_5C07  smd_2022_5C07
# 10   smd_2022_5D01  smd_2022_5D01
# 25   smd_2022_5D05  smd_2022_5D05
# 191  smd_2022_5E02  smd_2022_5E02
# 80   smd_2022_6A02  smd_2022_6A02
# 81   smd_2022_6A03  smd_2022_6A03
# 47   smd_2022_6A05  smd_2022_6A05
# 62   smd_2022_6B02  smd_2022_6B02
# 0    smd_2022_6B09  smd_2022_6B09
# 83   smd_2022_6C03  smd_2022_6C03
# 112  smd_2022_6D02  smd_2022_6D02
# 220  smd_2022_6D05  smd_2022_6D05
# 199  smd_2022_6D08  smd_2022_6D08
# 130  smd_2022_7B06  smd_2022_7B06
# 149  smd_2022_7F02  smd_2022_7F02
# 90   smd_2022_7F02  smd_2022_7F02
# 93   smd_2022_7F07  smd_2022_7F07
# 242  smd_2022_8A03  smd_2022_8A03
# 64   smd_2022_8A06  smd_2022_8A06
# 65   smd_2022_8B05  smd_2022_8B05
# 204  smd_2022_8C05  smd_2022_8C05
# 133  smd_2022_8C06  smd_2022_8C06
# 162  smd_2022_8E02  smd_2022_8E02
# 205  smd_2022_8E04  smd_2022_8E04
# 243  smd_2022_8F03  smd_2022_8F03

# %% [markdown]
# ## SMD Comparison
#
# This should be empty. If there's an disagreement on which district a candidate is running in, figure it out by the candidate's address.

# %%
(
    cd.loc[cd.smd_id_openanc != cd.smd_id_dcboe
    , ['candidate_name_openanc', 'candidate_name_dcboe', 'smd_id_openanc', 'smd_id_dcboe']]
    .sort_values(by='smd_id_openanc')
)
# Out:
# Empty DataFrame
# Columns: [candidate_name_openanc, candidate_name_dcboe, smd_id_openanc, smd_id_dcboe]
# Index: []

# %%
# This sum should be zero
# Once a candidate has a dcboe_hash_id, they should not have a manual status, generally
cd_left = pd.merge(cand, dcboe, how='left', on='dcboe_hash_id')
cd_left[cd_left.manual_status.notnull()].dcboe_hash_id.notnull().sum()
# Out:
# 0
