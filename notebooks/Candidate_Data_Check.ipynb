# %% [markdown]
# # Candidate Data Check
#
# Make sure the DCBOE hash IDs were pasted correctly, and generally check for other obvious problems with the `candidates` table.

# %%
import os
os.chdir('../')

import pandas as pd
pd.set_option('display.max_rows', 500)

from scripts.data_transformations import list_candidates

# %%
cand = list_candidates(election_year=2022)
dcboe = pd.read_csv('data/dcboe/candidates_dcboe.csv')

# %%
cd = pd.merge(cand, dcboe, how='inner', on='dcboe_hash_id', suffixes=['_openanc', '_dcboe'])

# %% [markdown]
# ## Candidate Name Comparison
#
# These candidates have a different name in DCBOE than in OpenANC. Compare them and consider changing to match the ballot.
#
# The "rejects" are names as they are rendered by DCBOE (initially uppercase, then fed through the Python title case function) that we have decided are not displayable.

# %%
dcboe_name_rejects = [
    'Alyce Mcfarland'
    , 'Andrew Mccarthy-Clark'
    , 'Mike Mclaughlin'
    , 'Susana Bara√Ëano'
    , 'Brian J. Mccabe'
    , 'Carl Edgar Rohde Iii'
    , 'Quentin Col√Ìn Roosevelt'
    , 'Thomas P. Defranco'
    , 'Nicole Mcentee'
    , 'V√Çctor De Le√Ìn'
    , 'Laqueda Tate'
    , 'Bobby \"Slli\'M" Williams'
    , 'Matt Lafortune'
    , 'Vj Kapur'
    , 'Steven Mccarty'
    , 'H Norman Knickle'
    , 'Obbie English'
    , 'Robin Mckinney'
    , 'Roric Mccorristin'
]

name_mismatches = (
    cd.loc[
        (cd.candidate_name_openanc != cd.candidate_name_dcboe)
        & ~cd.candidate_name_dcboe.isin(dcboe_name_rejects)
        & ~cd.candidate_name_dcboe.str.contains('Withdrew')
    , ['smd_id_openanc', 'candidate_name_openanc', 'candidate_name_dcboe']]
    .sort_values(by='smd_id_openanc')
)

print(len(name_mismatches))
name_mismatches
# Out:
# 59
#     smd_id_openanc       candidate_name_openanc         candidate_name_dcboe
# 408  smd_2022_1B03                  Muhsin Umar                  Mushin Umar
# 385  smd_2022_1B05              Alan Kensek Jr.                  Alan Kensek
# 388  smd_2022_1C08            Barney R. Shapiro             Barney R Shapiro
# 216  smd_2022_1D04          Yasmin Romero-Latin                Yasmin Romero
# 55   smd_2022_1E07                Amanda Farnan              Amanda M Farnan
# 56   smd_2022_2A03       Trupti "Trip" J. Patel          Trupti "Trip" Patel
# 57   smd_2022_2B02              Jeff Rueckgauer           Jeffrey Rueckgauer
# 144  smd_2022_2D02                  Carole Feld               Carole L. Feld
# 204  smd_2022_2E01                 Kishan Putta           Kishan Kumar Putta
# 242  smd_2022_2G01                   Tony Brown         Anthony "Tony" Brown
# 22   smd_2022_3C03                Janell Pagats          Janell Marie Pagats
# 120  smd_2022_3C05           Sauleh A. Siddiqui        Sauleh Ahmad Siddiqui
# 276  smd_2022_3C05                 Nicholas Ide          Nicholas (Nick) Ide
# 342  smd_2022_3D05        Christopher J. Rosier         Christopher J Rosier
# 249  smd_2022_3D05                 Bernard Horn                  Bernie Horn
# 147  smd_2022_3D07              J.P. Szymkowicz             J. P. Szymkowicz
# 69   smd_2022_3E02                  Amy B. Hall                   Amy B Hall
# 377  smd_2022_4B10              La Roya A. Huff               Laroya A. Huff
# 400  smd_2022_4C04       Yvette D. Marbury-Long          Yvette Marbury-Long
# 367  smd_2022_4D04   Chrysanthe "CC" Courniotes   Chrysanthe "Cc" Courniotes
# 75   smd_2022_4E01        Reginald E. Black Jr.    Reginald Eugene Black Jr.
# 269  smd_2022_4E02                 Marlene Moss            Marlene Hunt Moss
# 392  smd_2022_5A06      Derrick O. Holloway Sr.             Derrick Holloway
# 330  smd_2022_5A08       Gordon-Andrew Fletcher              Gordon Fletcher
# 254  smd_2022_5A09                Zach Ammerman             Zachary Ammerman
# 241  smd_2022_5B05           John J. Feeley Jr.                  John Feeley
# 122  smd_2022_5B07                 Gail Brevard              Gail A. Brevard
# 335  smd_2022_5C06             Harry Thomas Jr.     Harry "Tommy" Thomas Jr.
# 374  smd_2022_5D07                Juan McCullum                Juan Mccullum
# 393  smd_2022_5D09         Bernice S. Blacknell            Bernice Blacknell
# 331  smd_2022_5E04           Bertha G. Holliday              Bertha Holliday
# 218  smd_2022_5F03   Patricia Williams (Ward 5)            Patricia Williams
# 76   smd_2022_6A02            Michael Velasquez               Mike Velasquez
# 45   smd_2022_6A05                Laura Gentile              Laura L Gentile
# 59   smd_2022_6B02                Gerald Sroufe        Gerald "Jerry" Sroufe
# 272  smd_2022_6C07              Tony T. Goodman               Tony T Goodman
# 301  smd_2022_6D02            Ronald R. Collins               Ronald Collins
# 107  smd_2022_6D02               Thomas Seidman                  Tom Seidman
# 183  smd_2022_6D08           Rhonda N. Hamilton      Rhonda Natalie Hamilton
# 244  smd_2022_6E04            Denise E Blackson           Denise E. Blackson
# 256  smd_2022_7B04                D.L. Humphrey               D. L. Humphrey
# 222  smd_2022_7B04             David L. Retland           David "Dr" Retland
# 123  smd_2022_7B06                 Kelvin Brown            Kelvin Earl Brown
# 322  smd_2022_7C02   Patricia Williams (Ward 7)            Patricia Williams
# 80   smd_2022_7C09              Venola M. Rolle                 Venola Rolle
# 378  smd_2022_7D01              Siraaj M. Hasan                 Siraaj Hasan
# 84   smd_2022_7E05                   Tim Howard               Timothy Howard
# 140  smd_2022_7F02               Ashley R. Ruff            Ashley Renee Ruff
# 306  smd_2022_7F03          Kimory KSO Orendoff          Kimory Kso Orendoff
# 88   smd_2022_7F07                  Devon Myers                    Dev Myers
# 396  smd_2022_8A07             LaVerne R. Glenn                Laverne Glenn
# 62   smd_2022_8B05            Joseph B. Johnson               Joseph Johnson
# 187  smd_2022_8C05             Anthony Muhammad         Anthony Adc Muhammad
# 397  smd_2022_8D01              Homer L. Thomas               Homer L Thomas
# 334  smd_2022_8D05      Travon "Ward 8" Hawkins        Travon Ward 8 Hawkins
# 356  smd_2022_8E03      Shekita "Ki-Ki" McBroom       Shekita "Kiki" Mcbroom
# 379  smd_2022_8E04              Kendall Simmons  Kendall (The Voice) Simmons
# 171  smd_2022_8E06               Prokoshia Long                      P. Long
# 215  smd_2022_8F05  Clayton Aristotle Rosenberg            Clayton Rosenberg

# %% [markdown]
# ## SMD Comparison
#
# This should be empty. If there's an disagreement on which district a candidate is running in, figure it out by the candidate's address.

# %%
(
    cd.loc[cd.smd_id_openanc != cd.smd_id_dcboe
    , ['candidate_name_openanc', 'candidate_name_dcboe', 'smd_id_openanc', 'smd_id_dcboe']]
    .sort_values(by='smd_id_openanc')
)
# Out:
# Empty DataFrame
# Columns: [candidate_name_openanc, candidate_name_dcboe, smd_id_openanc, smd_id_dcboe]
# Index: []

# %%
# This sum should be zero
# Once a candidate has a dcboe_hash_id, they should not have a manual status, generally
cd_left = pd.merge(cand, dcboe, how='left', on='dcboe_hash_id')
cd_left[cd_left.manual_status.notnull()].dcboe_hash_id.notnull().sum()
# cd_left[cd_left.manual_status.notnull()]
# Out:
# 74

# %% [markdown]
# ## Candidate Duplicates
#
# Every person_id should only be in the candidate table once

# %%
cand.groupby('person_id').size()[cand.groupby('person_id').size() > 1]
# Out:
# Series([], dtype: int64)

# %%
cand.groupby('candidate_name').size()[cand.groupby('candidate_name').size() > 1]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# There are two different candidates named Patricia Williams.

# %% [markdown]
# ## person_id Integrity Check
#
# Are there any person_ids in the candidate table that are NOT in the person table?

# %%
c = pd.read_csv('data/candidates.csv')
p = pd.read_csv('data/people.csv')

# %%
[x for x in list(c.person_id) if x not in list(p.person_id)]
# Out:
# []
