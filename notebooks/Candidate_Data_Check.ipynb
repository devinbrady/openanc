# %% [markdown]
# # Candidate Data Check
#
# Make sure the DCBOE hash IDs were pasted correctly, and generally check for other obvious problems with the `candidates` table.

# %%
import os
os.chdir('../')

import pandas as pd
pd.set_option('display.max_rows', 500)

from scripts.data_transformations import list_candidates

# %%
cand = list_candidates(election_year=2022)
dcboe = pd.read_csv('data/dcboe/candidates_dcboe.csv')

# %%
cd = pd.merge(cand, dcboe, how='inner', on='dcboe_hash_id', suffixes=['_openanc', '_dcboe'])

# %% [markdown]
# ## Candidate Name Comparison
#
# These candidates have a different name in DCBOE than in OpenANC. Compare them and consider changing to match the ballot.
#
# The "rejects" are names as they are rendered by DCBOE (initially uppercase, then fed through the Python title case function) that we have decided are not displayable.

# %%
dcboe_name_rejects = [
    'Alyce Mcfarland'
    , 'Andrew Mccarthy-Clark'
    , 'Mike Mclaughlin'
    , 'Susana Bara√Ëano'
    , 'Brian J. Mccabe'
    , 'Carl Edgar Rohde Iii'
    , 'Quentin Col√Ìn Roosevelt'
    , 'Thomas P. Defranco'
    , 'Nicole Mcentee'
    , 'V√Çctor De Le√Ìn'
    , 'Laqueda Tate'
    , 'Bobby \"Slli\'M" Williams'
    , 'Matt Lafortune'
    , 'Vj Kapur'
    , 'Steven Mccarty'
    , 'H Norman Knickle'
    , 'Obbie English'
    , 'Robin Mckinney'
    , 'Roric Mccorristin'
]

name_mismatches = (
    cd.loc[
        (cd.candidate_name_openanc != cd.candidate_name_dcboe)
        & ~cd.candidate_name_dcboe.isin(dcboe_name_rejects)
        & ~cd.candidate_name_dcboe.str.contains('Withdrew')
    , ['smd_id_openanc', 'candidate_name_openanc', 'candidate_name_dcboe']]
    .sort_values(by='smd_id_openanc')
)

print(len(name_mismatches))
name_mismatches
# Out:
# 48
#     smd_id_openanc   candidate_name_openanc       candidate_name_dcboe
# 377  smd_2022_1B05           Deborah Thomas          Deborah R. Thomas
# 291  smd_2022_1B07             J. Swiderski             J.I. Swiderski
# 354  smd_2022_1C07          Jake Faleschini           Jacob Faleschini
# 247  smd_2022_1D04      Yasmin Romero-Latin              Yasmin Romero
# 59   smd_2022_1E07            Amanda Farnan            Amanda M Farnan
# 60   smd_2022_2A03   Trupti "Trip" J. Patel        Trupti "Trip" Patel
# 69   smd_2022_2A04       Carson Colton Robb                Carson Robb
# 61   smd_2022_2B02          Jeff Rueckgauer         Jeffrey Rueckgauer
# 154  smd_2022_2D02              Carole Feld             Carole L. Feld
# 278  smd_2022_2G01               Tony Brown       Anthony "Tony" Brown
# 23   smd_2022_3C03            Janell Pagats        Janell Marie Pagats
# 128  smd_2022_3C05       Sauleh A. Siddiqui      Sauleh Ahmad Siddiqui
# 393  smd_2022_3D05    Christopher J. Rosier       Christopher J Rosier
# 285  smd_2022_3D05             Bernard Horn                Bernie Horn
# 157  smd_2022_3D07          J.P. Szymkowicz           J. P. Szymkowicz
# 74   smd_2022_3E02              Amy B. Hall                 Amy B Hall
# 329  smd_2022_4A07       Carolyn C. Steptoe            Carolyn Steptoe
# 79   smd_2022_4C02         Antonia M. Kirby           Antoine M. Kirby
# 80   smd_2022_4E01    Reginald E. Black Jr.  Reginald Eugene Black Jr.
# 310  smd_2022_4E02             Marlene Moss          Marlene Hunt Moss
# 379  smd_2022_5A08   Gordon-Andrew Fletcher            Gordon Fletcher
# 292  smd_2022_5A09            Zach Ammerman           Zachary Ammerman
# 277  smd_2022_5B05       John J. Feeley Jr.                John Feeley
# 130  smd_2022_5B07             Gail Brevard            Gail A. Brevard
# 385  smd_2022_5C06         Harry Thomas Jr.   Harry "Tommy" Thomas Jr.
# 349  smd_2022_5D02        Sebrena L. Rhodes             Sebrena Rhodes
# 380  smd_2022_5E04       Bertha G. Holliday            Bertha Holliday
# 81   smd_2022_6A02        Michael Velasquez             Mike Velasquez
# 48   smd_2022_6A05            Laura Gentile            Laura L Gentile
# 63   smd_2022_6B02            Gerald Sroufe      Gerald "Jerry" Sroufe
# 84   smd_2022_6C03          Rasheedah Hasan         Rasheedah M. Hasan
# 314  smd_2022_6C07          Tony T. Goodman             Tony T Goodman
# 113  smd_2022_6D02           Thomas Seidman                Tom Seidman
# 348  smd_2022_6D02        Ronald R. Collins             Ronald Collins
# 200  smd_2022_6D08       Rhonda N. Hamilton    Rhonda Natalie Hamilton
# 280  smd_2022_6E04        Denise E Blackson         Denise E. Blackson
# 294  smd_2022_7B04            D.L. Humphrey             D. L. Humphrey
# 254  smd_2022_7B04         David L. Retland         David "Dr" Retland
# 131  smd_2022_7B06             Kelvin Brown          Kelvin Earl Brown
# 86   smd_2022_7C09          Venola M. Rolle               Venola Rolle
# 150  smd_2022_7F02           Ashley R. Ruff          Ashley Renee Ruff
# 353  smd_2022_7F04      Kimory KSO Orendoff        Kimory Kso Orendoff
# 94   smd_2022_7F07              Devon Myers                  Dev Myers
# 66   smd_2022_8B05        Joseph B. Johnson             Joseph Johnson
# 411  smd_2022_8B07  Rhonda L. Edwards-Hines       Rhonda Edwards-Hines
# 205  smd_2022_8C05         Anthony Muhammad       Anthony Adc Muhammad
# 384  smd_2022_8D05  Travon "Ward 8" Hawkins      Travon Ward 8 Hawkins
# 413  smd_2022_8E03  Shekita "Ki-Ki" McBroom     Shekita "Kiki" Mcbroom

# %% [markdown]
# ## SMD Comparison
#
# This should be empty. If there's an disagreement on which district a candidate is running in, figure it out by the candidate's address.

# %%
(
    cd.loc[cd.smd_id_openanc != cd.smd_id_dcboe
    , ['candidate_name_openanc', 'candidate_name_dcboe', 'smd_id_openanc', 'smd_id_dcboe']]
    .sort_values(by='smd_id_openanc')
)
# Out:
# Empty DataFrame
# Columns: [candidate_name_openanc, candidate_name_dcboe, smd_id_openanc, smd_id_dcboe]
# Index: []

# %%
# This sum should be zero
# Once a candidate has a dcboe_hash_id, they should not have a manual status, generally
cd_left = pd.merge(cand, dcboe, how='left', on='dcboe_hash_id')
cd_left[cd_left.manual_status.notnull()].dcboe_hash_id.notnull().sum()
cd_left[cd_left.manual_status.notnull()]
# Out:
#      candidate_id  person_id  election_year  \
# 4           50519      11356           2022
# 31          50546      11370           2022
# 198         50714      11460           2022
# 249         50766      10546           2022
# 254         50772      10178           2022
# 327         50845      11530           2022
#
#                                          dcboe_hash_id       smd_id_x  \
# 4                                                  NaN  smd_2022_7D07
# 31                                                 NaN  smd_2022_3E03
# 198                                                NaN  smd_2022_3E08
# 249                                                NaN  smd_2022_8F02
# 254  d6636977c7d7149b5c9f7ca10cf268612f96edba603301...  smd_2022_5E05
# 327                                                NaN  smd_2022_1B05
#
#           candidate_name_x              manual_status manual_source  \
# 4           Brian Voorhees  Declared Intention to Run           NaN
# 31        Thomas Marabello  Declared Intention to Run           NaN
# 198            Rohin Ghosh  Declared Intention to Run           NaN
# 249       Eric S. Blaylock  Declared Intention to Run           NaN
# 254  Robert Vinson Brannum                   Withdrew           NaN
# 327           Lindsay Webb  Declared Intention to Run           NaN
#
#      write-in winner according to DCBOE candidate_source_description  ...  \
# 4                                   NaN                          NaN  ...
# 31                                  NaN                          NaN  ...
# 198                                 NaN                          NaN  ...
# 249                                 NaN                          NaN  ...
# 254                                 NaN                          NaN  ...
# 327                                 NaN                          NaN  ...
#
#     filed_date_x dcboe_source                           dcboe_source_link  \
# 4            NaN          NaN                                         NaN
# 31           NaN          NaN                                         NaN
# 198          NaN          NaN                                         NaN
# 249          NaN          NaN                                         NaN
# 254          NaN        DCBOE  https://dcboe.org/Elections/2022-Elections
# 327          NaN          NaN                                         NaN
#
#     dcboe_updated_at  updated_at       smd_id_y       candidate_name_y  \
# 4                NaN  2022-07-14            NaN                    NaN
# 31               NaN  2022-07-29            NaN                    NaN
# 198              NaN  2022-07-26            NaN                    NaN
# 249              NaN  2022-07-27            NaN                    NaN
# 254       2022-08-08  2022-08-08  smd_2022_5E05  Robert Vinson Brannum
# 327              NaN  2022-08-03            NaN                    NaN
#
#      pickup_date_y filed_date_y        candidate_status_y
# 4              NaN          NaN                       NaN
# 31             NaN          NaN                       NaN
# 198            NaN          NaN                       NaN
# 249            NaN          NaN                       NaN
# 254     2022-07-27          NaN  Pulled Papers for Ballot
# 327            NaN          NaN                       NaN
#
# [6 rows x 29 columns]

# %% [markdown]
# ## Candidate Duplicates
#
# Every person_id should only be in the candidate table once

# %%
cand.groupby('person_id').size()[cand.groupby('person_id').size() > 1]
# Out:
# Series([], dtype: int64)

# %%
cand.groupby('candidate_name').size()[cand.groupby('candidate_name').size() > 1]
# Out:
# candidate_name
# Patricia Williams    2
# dtype: int64

# %% [markdown]
# There are two different candidates named Patricia Williams.
