# %% [markdown]
# # Candidate Data Check
#
# Make sure the DCBOE hash IDs were pasted correctly.

# %%
import os
os.chdir('../')

import pandas as pd
pd.set_option('display.max_rows', 500)

from scripts.data_transformations import list_commissioners, list_candidates

# %%
cand = list_candidates()
dcboe = pd.read_csv('data/dcboe/candidates_dcboe.csv')

# %%
cd = pd.merge(cand, dcboe, how='inner', on='dcboe_hash_id', suffixes=['_openanc', '_dcboe'])

# %% [markdown]
# ## Candidate Name Comparison
#
# These candidates have a different name in DCBOE than in OpenANC. Compare them and consider changing to match the ballot.

# %%
(
    cd.loc[cd.candidate_name_openanc != cd.candidate_name_dcboe
    , ['candidate_name_openanc', 'candidate_name_dcboe', 'smd_id_openanc', 'smd_id_dcboe']]
    .sort_values(by='smd_id_openanc')
)
# Out:
#       candidate_name_openanc                        candidate_name_dcboe  \
# 292             J. Swiderski                              J.I. Swiderski
# 248      Yasmin Romero-Latin                               Yasmin Romero
# 214          Mike McLaughlin                             Mike Mclaughlin
# 59             Amanda Farnan                             Amanda M Farnan
# 282          Susana Barañano                            Susana Bara√Ëano
# 60    Trupti "Trip" J. Patel                         Trupti "Trip" Patel
# 69        Carson Colton Robb                                 Carson Robb
# 61           Jeff Rueckgauer                          Jeffrey Rueckgauer
# 154              Carole Feld                              Carole L. Feld
# 71           Brian J. McCabe                             Brian J. Mccabe
# 279               Tony Brown                        Anthony "Tony" Brown
# 304           Steven McCarty                              Steven Mccarty
# 238     Carl Edgar Rohde III                        Carl Edgar Rohde Iii
# 263        H. Norman Knickle                            H Norman Knickle
# 23             Janell Pagats                         Janell Marie Pagats
# 128       Sauleh A. Siddiqui                       Sauleh Ahmad Siddiqui
# 21   Quentin Colón Roosevelt                    Quentin Col√Ìn Roosevelt
# 157          J.P. Szymkowicz                            J. P. Szymkowicz
# 74               Amy B. Hall                                  Amy B Hall
# 79          Antonia M. Kirby                            Antoine M. Kirby
# 80     Reginald E. Black Jr.                   Reginald Eugene Black Jr.
# 293            Zach Ammerman                            Zachary Ammerman
# 278       John J. Feeley Jr.                                 John Feeley
# 130             Gail Brevard                             Gail A. Brevard
# 18                  VJ Kapur                                    Vj Kapur
# 11          Luc Saint-Genies                    Luc Raphael Saint Genies
# 26   Salvador Sauceda-Guzman  Salvador "The Commissioner" Sauceda-Guzman
# 258      Joyce Robinson-Paul             Joyce (Statehood) Robinson-Paul
# 193           Nicole McEntee                              Nicole Mcentee
# 81         Michael Velasquez                              Mike Velasquez
# 48             Laura Gentile                             Laura L Gentile
# 63             Gerald Sroufe                       Gerald "Jerry" Sroufe
# 0             Matt LaFortune                              Matt Lafortune
# 84           Rasheedah Hasan                          Rasheedah M. Hasan
# 113           Thomas Seidman                                 Tom Seidman
# 222           Víctor de León                            V√Çctor De Le√Ìn
# 201       Rhonda N. Hamilton                     Rhonda Natalie Hamilton
# 281        Denise E Blackson                          Denise E. Blackson
# 295            D.L. Humphrey                              D. L. Humphrey
# 255         David L. Retland                          David "Dr" Retland
# 131             Kelvin Brown                           Kelvin Earl Brown
# 150           Ashley R. Ruff                           Ashley Renee Ruff
# 91         Obbie English III                               Obbie English
# 94               Devon Myers                                   Dev Myers
# 244  Bobby "Slli'm" Williams                     Bobby "Slli'M" Williams
# 65            Robin McKinney                              Robin Mckinney
# 66         Joseph B. Johnson                              Joseph Johnson
# 206         Anthony Muhammad                        Anthony Adc Muhammad
# 134          Robbie Woodland              Robbie "The Advocate" Woodland
# 163             LaQueta Tate                                Laqueda Tate
# 207           Shaquan Hudson               Shaquan "Living Proof" Hudson
# 245    Andrew McCarthy-Clark                       Andrew Mccarthy-Clark
#
#       smd_id_openanc     smd_id_dcboe
# 292    smd_2022_1B07    smd_2022_1B07
# 248    smd_2022_1D04    smd_2022_1D04
# 214    smd_2022_1E04    smd_2022_1E04
# 59     smd_2022_1E07    smd_2022_1E07
# 282    smd_2022_2A01    smd_2022_2A01
# 60     smd_2022_2A03    smd_2022_2A03
# 69     smd_2022_2A04    smd_2022_2A04
# 61     smd_2022_2B02    smd_2022_2B02
# 154    smd_2022_2D02    smd_2022_2D02
# 71     smd_2022_2F04    smd_2022_2F04
# 279    smd_2022_2G01    smd_2022_2G01
# 304    smd_2022_2G04    smd_2022_2G04
# 238    smd_2022_2G06    smd_2022_2G06
# 263  smd_2022_3/4G05  smd_2022_3/4G05
# 23     smd_2022_3C03    smd_2022_3C03
# 128    smd_2022_3C05    smd_2022_3C05
# 21     smd_2022_3D03    smd_2022_3D03
# 157    smd_2022_3D07    smd_2022_3D07
# 74     smd_2022_3E02    smd_2022_3E02
# 79     smd_2022_4C02    smd_2022_4C02
# 80     smd_2022_4E01    smd_2022_4E01
# 293    smd_2022_5A09    smd_2022_5A09
# 278    smd_2022_5B05    smd_2022_5B05
# 130    smd_2022_5B07    smd_2022_5B07
# 18     smd_2022_5C07    smd_2022_5C07
# 11     smd_2022_5D01    smd_2022_5D01
# 26     smd_2022_5D05    smd_2022_5D05
# 258    smd_2022_5E01    smd_2022_5E01
# 193    smd_2022_5E02    smd_2022_5E02
# 81     smd_2022_6A02    smd_2022_6A02
# 48     smd_2022_6A05    smd_2022_6A05
# 63     smd_2022_6B02    smd_2022_6B02
# 0      smd_2022_6B09    smd_2022_6B09
# 84     smd_2022_6C03    smd_2022_6C03
# 113    smd_2022_6D02    smd_2022_6D02
# 222    smd_2022_6D05    smd_2022_6D05
# 201    smd_2022_6D08    smd_2022_6D08
# 281    smd_2022_6E04    smd_2022_6E04
# 295    smd_2022_7B04    smd_2022_7B04
# 255    smd_2022_7B04    smd_2022_7B04
# 131    smd_2022_7B06    smd_2022_7B06
# 150    smd_2022_7F02    smd_2022_7F02
# 91     smd_2022_7F02    smd_2022_7F02
# 94     smd_2022_7F07    smd_2022_7F07
# 244    smd_2022_8A03    smd_2022_8A03
# 65     smd_2022_8A06    smd_2022_8A06
# 66     smd_2022_8B05    smd_2022_8B05
# 206    smd_2022_8C05    smd_2022_8C05
# 134    smd_2022_8C06    smd_2022_8C06
# 163    smd_2022_8E02    smd_2022_8E02
# 207    smd_2022_8E04    smd_2022_8E04
# 245    smd_2022_8F03    smd_2022_8F03

# %% [markdown]
# ## SMD Comparison
#
# This should be empty. If there's an disagreement on which district a candidate is running in, figure it out by the candidate's address.

# %%
(
    cd.loc[cd.smd_id_openanc != cd.smd_id_dcboe
    , ['candidate_name_openanc', 'candidate_name_dcboe', 'smd_id_openanc', 'smd_id_dcboe']]
    .sort_values(by='smd_id_openanc')
)
# Out:
# Empty DataFrame
# Columns: [candidate_name_openanc, candidate_name_dcboe, smd_id_openanc, smd_id_dcboe]
# Index: []

# %%
# This sum should be zero
# Once a candidate has a dcboe_hash_id, they should not have a manual status, generally
cd_left = pd.merge(cand, dcboe, how='left', on='dcboe_hash_id')
cd_left[cd_left.manual_status.notnull()].dcboe_hash_id.notnull().sum()
# Out:
# 0

# %% [markdown]
# ## Candidate Duplicates
#
# Every person_id should only be in the candidate table once

# %%
cand.groupby('person_id').size()[cand.groupby('person_id').size() > 1]
# Out:
# Series([], dtype: int64)

# %%
cand.groupby('candidate_name').size()[cand.groupby('candidate_name').size() > 1]
# Out:
# Series([], dtype: int64)
