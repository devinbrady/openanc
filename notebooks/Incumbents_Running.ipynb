# %% [markdown]
# # Are Incumbents Running for Re-Election?
#
# Check incumbents to make sure they are running for re-election

# %%
import os
os.chdir('../')

import pandas as pd
pd.set_option('display.max_rows', 500)

from scripts.data_transformations import (
    list_commissioners
    , list_candidates
)

# %%
people = pd.read_csv('data/people.csv')
comm = list_commissioners(status='current')
pc = pd.merge(people, comm, how='inner', on='person_id')

candidates = list_candidates()
candidates['is_running'] = True

not_running = pd.read_csv('data/incumbents_not_running.csv')
not_running['confirmed_not_running'] = True

# %%
comm_candidates = pd.merge(
    pc
    , candidates[['person_id', 'candidate_id', 'is_running']]
    , how='left'
    , on='person_id'
)

comm_candidates_nr = pd.merge(
    comm_candidates
    , not_running[['person_id', 'confirmed_not_running']]
    , how='left'
    , on='person_id'
)

comm_candidates_nr['candidate_status'] = 'unknown'

# %%
comm_candidates_nr.loc[comm_candidates_nr.confirmed_not_running.fillna(False), 'candidate_status'] = 'not running'
comm_candidates_nr.loc[comm_candidates_nr.is_running.fillna(False), 'candidate_status'] = 'is running'

# %%
comm_candidates_nr.groupby('candidate_status').size()
# Out:
# candidate_status
# is running      76
# not running      5
# unknown        207
# dtype: int64

# %%
comm_candidates_nr[(comm_candidates_nr.candidate_status == 'unknown') & (comm_candidates_nr.twitter_link.notnull())][
    ['person_id', 'full_name', 'smd_id', 'twitter_link']
].sort_values(by='smd_id', ascending=False)
# Out:
#      person_id                    full_name    smd_id  \
# 194      10442     Brittany Geneva Cummings  smd_8E06
# 276      11342                Devon Lesesne  smd_8D06
# 136      10275               Ellen Armstead  smd_8D05
# 135      10274              Monique T. Diop  smd_8D04
# 212      10492                Steven Tiller  smd_8A07
# 189      10424                 Jamila White  smd_8A05
# 123      10250               Holly Muhammad  smd_8A01
# 120      10244            Tyrell M. Holcomb  smd_7F01
# 234      10549              Kimberly Martin  smd_7E07
# 118      10242                Delia Houseal  smd_7E06
# 186      10412                Natasha Dupee  smd_7E04
# 117      10237                 Veda Rasheed  smd_7E01
# 225      10516             Stephanie Audain  smd_7D05
# 115      10232              Siraaj M. Hasan  smd_7D02
# 183      10408               Victoria Clark  smd_7C06
# 182      10406                    Vince Van  smd_7C03
# 109      10224                D.L. Humphrey  smd_7B07
# 108      10219             Tiffany L. Brown  smd_7B02
# 180      10399             Chioma J. Iwuoha  smd_7B01
# 223      10512            Patrick K. Parlej  smd_6E05
# 255      10610                  Jared Weiss  smd_6D02
# 99       10203                Drew Courtney  smd_6C06
# 93       10197  Kathryn Denise Rucker Krepp  smd_6B10
# 240      10564                 Peter Wright  smd_6B08
# 92       10194                 Corey Holman  smd_6B06
# 91       10193              Steven Holtzman  smd_6B05
# 90       10192            Kirsten Oldenburg  smd_6B04
# 89       10191                  Brian Ready  smd_6B03
# 85       10187      Sondra Phillips-Gilbert  smd_6A07
# 239      10562                Sally Hobaugh  smd_5E10
# 81       10179                Dianne Barnes  smd_5E09
# 80       10178        Robert Vinson Brannum  smd_5E08
# 77       10175        Bradley Ashton Thomas  smd_5E05
# 173      10371              Zachary Hoffman  smd_5D06
# 74       10169                Sydelle Moore  smd_5D05
# 172      10369                 Latoya Moore  smd_5D03
# 170      10365            Sebrena L. Rhodes  smd_5D01
# 232      10541    Sukhprita "Prita" Piekara  smd_5B03
# 61       10148           Emily Singer Lucio  smd_5A03
# 169      10357          Damion McDuffie Sr.  smd_5A01
# 257      10612                   Eric Smith  smd_4D05
# 210      10482               Zachary Israel  smd_4D04
# 220      10507      Aryan Rodriguez Bocquet  smd_4D03
# 59       10141              Renée L. Bowser  smd_4D02
# 237      10557                 Erik Lindsjo  smd_4D01
# 58       10139                Jonah Goodman  smd_4C10
# 209      10481       Clara Haskell Botstein  smd_4C08
# 167      10353         Namatie Sia Mansaray  smd_4C06
# 197      10447      Audrey Anderson Duckett  smd_4C05
# 57       10132          Ulysses E. Campbell  smd_4C03
# 165      10349                Vanessa Rubio  smd_4C01
# 55       10129              La Roya A. Huff  smd_4B09
# 53       10127              Geoff Bromaghim  smd_4B07
# 163      10345   Pavan Ishwar Khoobchandani  smd_4A08
# 48       10118         Candace Tiana Nelson  smd_4A06
# 45       10115               Stacey Lincoln  smd_4A02
# 277      11343              Charles Cadwell  smd_3G07
# 162      10341            Connie K.N. Chang  smd_3G05
# 249      10593               Michael Zeldin  smd_3G04
# 245      10575                 Stanley Wall  smd_3F04
# 207      10478             Alexandria Appah  smd_3F02
# 41       10101               David Cristeal  smd_3F01
# 40       10099                    Tom Quinn  smd_3E04
# 39       10098              Jonathan Bender  smd_3E03
# 156      10329            Christian Damiana  smd_3D07
# 33       10086                 Chuck Elkins  smd_3D01
# 218      10502                 Adam M. Hoyt  smd_3C06
# 29       10079                   Jason Fink  smd_3C02
# 27       10077             Brian G. Turmail  smd_3B05
# 229      10521             Alexandra Bailey  smd_2F08
# 281      11347            Maxime Devilliers  smd_2F06
# 228      10520               Sherene Joseph  smd_2F05
# 23       10068                 John Fanning  smd_2F04
# 205      10472                 Michelle Yan  smd_2F03
# 22       10066               John Guggenmos  smd_2F02
# 152      10318             Brian Romanowski  smd_2F01
# 17       10057                 Kishan Putta  smd_2E01
# 202      10462                Ashley Warren  smd_2D01
# 150      10313                  Gigi Nelson  smd_2C03
# 16       10052           Michael D. Shankle  smd_2C01
# 149      10312                 Kyle Mulhall  smd_2B09
# 14       10047               Randy D. Downs  smd_2B07
# 15       10048             Mike Silverstein  smd_2B06
# 196      10445               William Herbig  smd_2B05
# 263      10623            Margaret McDonald  smd_2A08
# 254      10606               Donna Barbisch  smd_2A04
# 252      10604               Yannik Omictin  smd_2A01
# 11       10035          Chelsea A. Allinger  smd_1D05
# 243      10570           Matthew Brandeburg  smd_1D04
# 10       10033                   Jack McKay  smd_1D03
# 235      10551               Jason Hamacher  smd_1D01
# 143      10301                   Fiona Clem  smd_1C08
# 271      10632              Jake Faleschini  smd_1C07
# 231      10529           Benjamin Hart Butz  smd_1C06
# 275      11341               Deb Felsenthal  smd_1C05
# 6        10014                 Dan Orlaskey  smd_1B02
# 4        10010                Rashida Brown  smd_1A10
# 3        10009                 Michael Wray  smd_1A09
# 2        10008                Kent C. Boese  smd_1A08
# 268      10629            Brandolon Barnett  smd_1A06
# 0        10001                 Layla Bonnot  smd_1A01
#
#                             twitter_link
# 194           https://twitter.com/bgc4dc
# 276   https://twitter.com/TheeBlackAnglo
# 136  https://twitter.com/commisharmstead
# 135         https://twitter.com/MoniDiop
# 212      https://twitter.com/STiller8A07
# 189    https://twitter.com/JamilaWhiteDC
# 123     https://twitter.com/soldbyhollym
# 120        https://twitter.com/tmholcomb
# 234          https://twitter.com/KNMar10
# 118     https://twitter.com/DeliaHouseal
# 186       https://twitter.com/DupeeforDC
# 117      https://twitter.com/VedaRasheed
# 225    https://twitter.com/AudainANC7D05
# 115  https://twitter.com/Siraaj_CEO_SMSB
