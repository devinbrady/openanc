# %% [markdown]
# # Open Seats by Districts
#
# Which ANCs and wards have the most districts without any candidates?

# %%
import os
os.chdir('../')

import pandas as pd
pd.set_option('display.max_rows', 500)

from scripts.data_transformations import (
    list_commissioners
    , list_candidates
)

# %%
candidates = list_candidates(election_year=2022)
districts = pd.read_csv('data/districts.csv')
districts = districts[districts.redistricting_year == 2022].copy()
ancs = pd.read_csv('data/ancs.csv')
wards = pd.read_csv('data/wards.csv')

# %%
districts = pd.merge(districts, ancs, how='inner', on='anc_id')
districts = pd.merge(districts, wards, how='inner', on='ward_id')

# %%
districts = pd.merge(
    districts
    , pd.DataFrame(candidates.groupby('smd_id').size(), columns=['num_candidates']).reset_index()
    , how='left'
    , on='smd_id'
)

# %%
districts['num_candidates'] = districts['num_candidates'].fillna(0)

districts['no_candidate_districts'] = 0
districts.loc[districts.num_candidates == 0, 'no_candidate_districts'] = 1

# %%
candidates_by_anc = districts.groupby('anc_id').agg(
    num_districts=('smd_id', 'size')
    , no_candidate_districts=('no_candidate_districts', 'sum')
)
candidates_by_anc['percentage_no_candidate'] = (
    candidates_by_anc.no_candidate_districts / candidates_by_anc.num_districts
)

# %%
candidates_by_anc.sort_values(by=['percentage_no_candidate', 'no_candidate_districts'], ascending=False)
# Out:
#                num_districts  no_candidate_districts  percentage_no_candidate
# anc_id
# anc_8D_2022                8                       5                 0.625000
# anc_6E_2022                9                       5                 0.555556
# anc_2C_2022                4                       2                 0.500000
# anc_7E_2022                7                       3                 0.428571
# anc_2E_2022                8                       3                 0.375000
# anc_2F_2022                8                       2                 0.250000
# anc_7F_2022                8                       2                 0.250000
# anc_1C_2022                9                       2                 0.222222
# anc_5A_2022                9                       2                 0.222222
# anc_5D_2022                9                       2                 0.222222
# anc_8E_2022                9                       2                 0.222222
# anc_7D_2022               10                       2                 0.200000
# anc_3A_2022                5                       1                 0.200000
# anc_3B_2022                6                       1                 0.166667
# anc_1D_2022                7                       1                 0.142857
# anc_1E_2022                7                       1                 0.142857
# anc_4A_2022                7                       1                 0.142857
# anc_4C_2022                7                       1                 0.142857
# anc_8A_2022                7                       1                 0.142857
# anc_8B_2022                7                       1                 0.142857
# anc_3E_2022                8                       1                 0.125000
# anc_4D_2022                8                       1                 0.125000
# anc_6D_2022                8                       1                 0.125000
# anc_1B_2022                9                       1                 0.111111
# anc_7B_2022                9                       1                 0.111111
# anc_1A_2022               10                       0                 0.000000
# anc_2A_2022                9                       0                 0.000000
# anc_2B_2022                9                       0                 0.000000
# anc_2D_2022                2                       0                 0.000000
# anc_2G_2022                6                       0                 0.000000
# anc_3/4G_2022              7                       0                 0.000000
# anc_3C_2022                8                       0                 0.000000
# anc_3D_2022                7                       0                 0.000000
# anc_3F_2022                6                       0                 0.000000
# anc_4B_2022               10                       0                 0.000000
# anc_4E_2022                6                       0                 0.000000
# anc_5B_2022                7                       0                 0.000000
# anc_5C_2022                7                       0                 0.000000
# anc_5E_2022                6                       0                 0.000000
# anc_5F_2022                7                       0                 0.000000
# anc_6/8F_2022              5                       0                 0.000000
# anc_6A_2022                7                       0                 0.000000
# anc_6B_2022                9                       0                 0.000000
# anc_6C_2022                7                       0                 0.000000
# anc_7C_2022                9                       0                 0.000000
# anc_8C_2022                8                       0                 0.000000

# %%
sorted(ancs[ancs.notes.fillna('').str.contains('new')].anc_name)
# Out:
# ['ANC 1E', 'ANC 2G', 'ANC 3A', 'ANC 4E', 'ANC 5F', 'ANC 6/8F']

# %%
candidates_by_anc.sum()
# Out:
# num_districts              345.000000
# no_candidate_districts      45.000000
# percentage_no_candidate      5.894048
# dtype: float64

# %%
candidates_by_ward = districts.groupby('ward_id').agg(
    num_districts=('smd_id', 'size')
    , no_candidate_districts=('no_candidate_districts', 'sum')
)
candidates_by_ward #.sort_values(by='no_candidate_districts', ascending=False)
# Out:
#              num_districts  no_candidate_districts
# ward_id
# ward_1_2022             42                       5
# ward_2_2022             46                       7
# ward_3_2022             43                       3
# ward_4_2022             42                       3
# ward_5_2022             45                       4
# ward_6_2022             42                       6
# ward_7_2022             43                       8
# ward_8_2022             42                       9

# %%
candidates_by_ward.sum()
# Out:
# num_districts             345
# no_candidate_districts     45
# dtype: int64

# %%
candidate_count = pd.pivot_table(
    data=districts
    , columns='num_candidates'
    , index='ward_name'
    , aggfunc='size'
    , fill_value=0
)

candidate_count['Total'] = candidate_count.sum(axis=1)
candidate_count.loc['Total'] = candidate_count.sum(axis=0)
candidate_count.index.name = 'Ward'
candidate_count.columns.name = 'Number of Candidates'

candidate_count
# Out:
# Number of Candidates  0.0  1.0  2.0  3.0  4.0  Total
# Ward
# Ward 1                  5   25    9    3    0     42
# Ward 2                  7   25   12    2    0     46
# Ward 3                  3   24   14    2    0     43
# Ward 4                  3   25   12    2    0     42
# Ward 5                  4   20   21    0    0     45
# Ward 6                  6   25    9    1    1     42
# Ward 7                  8   21    9    5    0     43
# Ward 8                  9    9   16    8    0     42
# Total                  45  174  102   23    1    345

# %%
candidate_count = pd.pivot_table(
    data=districts
    , columns='num_candidates'
    , index='anc_name'
    , aggfunc='size'
    , fill_value=0
)

candidate_count['Total'] = candidate_count.sum(axis=1)
candidate_count.loc['Total'] = candidate_count.sum(axis=0)
candidate_count.index.name = 'ANC'
candidate_count.columns.name = 'Number of Candidates'

candidate_count
# Out:
# Number of Candidates  0.0  1.0  2.0  3.0  4.0  Total
# ANC
# ANC 1A                  0    8    1    1    0     10
# ANC 1B                  1    5    3    0    0      9
# ANC 1C                  2    5    1    1    0      9
# ANC 1D                  1    4    2    0    0      7
# ANC 1E                  1    3    2    1    0      7
# ANC 2A                  0    6    2    1    0      9
# ANC 2B                  0    7    2    0    0      9
# ANC 2C                  2    1    1    0    0      4
# ANC 2D                  0    2    0    0    0      2
# ANC 2E                  3    3    2    0    0      8
# ANC 2F                  2    6    0    0    0      8
# ANC 2G                  0    0    5    1    0      6
# ANC 3/4G                0    5    2    0    0      7
# ANC 3A                  1    4    0    0    0      5
# ANC 3B                  1    4    0    1    0      6
# ANC 3C                  0    3    5    0    0      8
# ANC 3D                  0    3    4    0    0      7
# ANC 3E                  1    5    2    0    0      8
# ANC 3F                  0    3    2    1    0      6
# ANC 4A                  1    3    2    1    0      7
# ANC 4B                  0    8    1    1    0     10
# ANC 4C                  1    5    1    0    0      7
# ANC 4D                  1    4    3    0    0      8
# ANC 4E                  0    2    4    0    0      6
# ANC 5A                  2    6    1    0    0      9
# ANC 5B                  0    2    5    0    0      7
# ANC 5C                  0    5    2    0    0      7
# ANC 5D                  2    3    4    0    0      9
# ANC 5E                  0    2    4    0    0      6
# ANC 5F                  0    2    5    0    0      7
# ANC 6/8F                0    1    3    0    1      5
# ANC 6A                  0    3    3    1    0      7
# ANC 6B                  0    9    0    0    0      9
# ANC 6C                  0    5    2    0    0      7
# ANC 6D                  1    4    3    0    0      8
# ANC 6E                  5    4    0    0    0      9
# ANC 7B                  1    5    2    1    0      9
# ANC 7C                  0    4    3    2    0      9
# ANC 7D                  2    5    3    0    0     10
# ANC 7E                  3    4    0    0    0      7
# ANC 7F                  2    3    1    2    0      8
# ANC 8A                  1    2    3    1    0      7
# ANC 8B                  1    3    2    1    0      7
# ANC 8C                  0    1    3    4    0      8
# ANC 8D                  5    0    2    1    0      8
# ANC 8E                  2    2    4    1    0      9
# Total                  45  174  102   23    1    345

# %%
districts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 345 entries, 0 to 344
# Data columns (total 38 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   smd_id                  345 non-null    object
#  1   smd_name                345 non-null    object
#  2   sort_order_x            345 non-null    int64
#  3   redistricting_year_x    345 non-null    int64
#  4   redistricting_cycle_x   345 non-null    object
#  5   anc_id                  345 non-null    object
#  6   ward_id                 345 non-null    object
#  7   centroid_lon_x          345 non-null    float64
#  8   centroid_lat_x          345 non-null    float64
#  9   area_x                  0 non-null      float64
#  10  map_color_id            345 non-null    int64
#  11  neighbor_smds           345 non-null    object
#  12  overlap_smds            345 non-null    object
#  13  overlap_percentage_x    345 non-null    object
#  14  notes_x                 0 non-null      object
#  15  description             0 non-null      object
#  16  landmarks               0 non-null      object
#  17  anc_name                345 non-null    object
#  18  sort_order_y            345 non-null    int64
#  19  redistricting_year_y    345 non-null    int64
#  20  redistricting_cycle_y   345 non-null    object
#  21  dc_oanc_link            0 non-null      object
#  22  anc_homepage_link       0 non-null      object
#  23  centroid_lon_y          345 non-null    float64
#  24  centroid_lat_y          345 non-null    float64
#  25  area_y                  345 non-null    int64
#  26  neighborhoods           0 non-null      object
#  27  twitter_link            0 non-null      object
#  28  neighbor_ancs           0 non-null      float64
#  29  overlap_ancs            345 non-null    object
#  30  overlap_percentage_y    345 non-null    object
#  31  notes_y                 43 non-null     object
#  32  ward_name               345 non-null    object
#  33  redistricting_year      345 non-null    int64
#  34  redistricting_cycle     345 non-null    object
#  35  councilmember           345 non-null    object
#  36  num_candidates          345 non-null    float64
#  37  no_candidate_districts  345 non-null    int64
# dtypes: float64(7), int64(8), object(23)
# memory usage: 115.1+ KB
